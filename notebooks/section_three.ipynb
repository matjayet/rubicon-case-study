# %% [markdown]
# ## Section Three: Deep Learning - Model Fine-Tuning for Crop Mapping
#
# In this section, you will implement a pipeline that fine-tunes a pretrained segmentation model to
# perform crop mapping using Sentinel-2 imagery.
# ### Objective:
#
# Your task is to:
# - Fine-tune a pretrained segmentation model. You can use the same model from section
# 2, or pick another one. Some potential options include U-Net or DeepLabV3+.
# - The model should classify crop type (e.g., Wheat, Rice, Maize, Vegetation, Bare Soil).
# - Evaluate the model's performance on a validation set and report on its effectiveness in
# mapping different crop types.
# ### Notes:
# - **Dataset Choice**: Choose a dataset suitable for crop mapping tasks. This could be a
# simpler one like Munich480, or more extensive ones available on Google Earth Engine
# or Kaggle.
# - Provide any files that you think are useful for the evaluation of your model, learning
# curves, metrics and such. This should include your code, the model weights or
# checkpoints, and any visuals and explanations you think are relevant.
# - Given the allotted time, focus on having clean, reproducible code. The goal of this last
# section is to understand how you could approach a fine-tuning task.

# %% [markdown]
# ## 🌾 Fine-Tuning a Model for Crop Type Classification (What I Would Have Done)
#
# Unfortunately, I didn’t have enough time to complete this part due to limited access to Colab’s GPU and the constraints of working on a slower personal machine with large datasets. I prefered to keep the time I had to improve/clean the first two sections.
#
# That said, here is what I **would have done to fine-tune a model** for crop type classification:
#
# ### 1. 🗂️ Find a Suitable Dataset
# - The first step would be to find a relevant dataset that includes **crop type annotations**. Ideally, the dataset should:
#   - Be large enough to support generalization.
#   - Contain classes that match our objectives (i.e. crop types).
#   - Be in a compatible format — some models (like YOLO) don’t use GeoTIFFs for labels, but instead require **polygon annotations** for each object/class.
#
# - If the model will later be applied to external data, it’s crucial to understand and **reproduce the same preprocessing** used in the dataset:
#   - What satellite imagery is used? (e.g., Sentinel-2 L2A?)
#   - Which spectral bands are included?
#   - How are the images normalized or augmented?
#
# ### 2. 🔄 Convert and Clean the Dataset
# - If necessary, convert the dataset into the format required by the model/framework (e.g., TensorFlow, PyTorch, or YOLO).
# - Consider simplifying the dataset:
#   - **Reduce the number of classes** to only those that are relevant.
#   - **Drop unnecessary bands** to reduce model complexity and training time.
#   - This can lead to faster training and better performance.
#   - Split dataset in test/train/val if it is not already done
#
# ### 3. 🧠 Select a Model Architecture
# - Choose an appropriate model architecture based on research and prior work.
# - Ideally, use a **pretrained model** — transfer learning can significantly improve performance and reduce training time.
#   - It's okay if the pretrained model isn’t a perfect fit, as we’ll be fine-tuning it on our dataset.
#   - Ensure the **input shape is compatible** or adaptable.
#
# ### 4. ⚙️ Adjust Hyperparameters
# - Tune key hyperparameters like:
#   - Optimizer (Adam for example)
#   - Learning rate
#   - Batch size
#   - Dropout rates
# - These can be adjusted manually or through experimentation.
# - Use model versioning like MLFlow to keep track of the different results (especially if you use more than one model)
#
# ### 5. 🚀 Data Augmentation and Training the Model
# - To increase the robustness of the model we may want to implement **data augmentation** techniques like:
#   - Random rotations
#   - Flips
#   - Brightness and contrast adjustments
#   - Cropping and scaling
#
#   This helps the model generalize better by exposing it to a wider variety of data.
#
# - Use a GPU environment like Colab to speed up training.
# - Monitor training progress with:
#   - Validation loss/accuracy
#   - Early stopping to prevent overfitting
#   - Model checkpointing to save the best weights
#
# - If training is too slow:
#   - Consider simplifying the dataset (fewer classes, lower resolution)
#   - Try a lighter model architecture
#
# ### 6. 📊 Analyzing the Results
# - Evaluate both qualitatively and quantitatively:
#   - **Training curves**: Is validation loss still decreasing? Signs of overfitting?
#   - **Global metrics**: Accuracy, precision, recall, F1-score. How does my model perform classifying pixels
#   - **Confusion matrix**: Which crop types are well classified? Are two or more often mixed up together ?
# - Don’t forget to evaluate on a **test set the model has never seen** to get a true measure of generalization.

# %% [markdown]
# **Possible datasets :**
#
# https://huggingface.co/datasets/IGNF/PASTIS-HD/blob/main/README.md?code=true#L14
#
# https://www.kaggle.com/datasets/artelabsuper/sentinel2-munich480
#
# https://huggingface.co/datasets/GFM-Bench/SegMunich/blob/main/README.md

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("artelabsuper/sentinel2-munich480")

print("Path to dataset files:", path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import kagglehub
#       3 # Download latest version
#       4 path = kagglehub.dataset_download("artelabsuper/sentinel2-munich480")
#
# File ~/.pyenv/versions/rubicon/lib/python3.10/site-packages/kagglehub/__init__.py:4
#       1 __version__ = "0.3.11"
#       3 import kagglehub.logger  # configures the library logger.
# ----> 4 from kagglehub import colab_cache_resolver, http_resolver, kaggle_cache_resolver, registry
#       5 from kagglehub.auth import login, whoami
#       6 from kagglehub.competition import competition_download
#
# File ~/.pyenv/versions/rubicon/lib/python3.10/site-packages/kagglehub/colab_cache_resolver.py:11
#       9 from kagglehub.handle import DatasetHandle, ModelHandle
#      10 from kagglehub.logger import EXTRA_CONSOLE_BLOCK
# ...

# %%
from datasets import load_dataset

dataset = load_dataset("GFM-Bench/SegMunich")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 from datasets import load_dataset
# ----> 3 dataset = load_dataset("GFM-Bench/SegMunich")
#
# File ~/.pyenv/versions/rubicon/lib/python3.10/site-packages/datasets/load.py:2084, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2081     return builder_instance.as_streaming_dataset(split=split)
#    2083 # Download and prepare data
# -> 2084 builder_instance.download_and_prepare(
#    2085     download_config=download_config,
#    2086     download_mode=download_mode,
#    2087     verification_mode=verification_mode,
#    2088     num_proc=num_proc,
#    2089     storage_options=storage_options,
# ...
